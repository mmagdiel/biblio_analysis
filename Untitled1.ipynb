# %%
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbs
import matplotlib.pyplot as plt

# Options for plots
plt.rcParams['figure.figsize'] = (10, 6)
sbs.set('paper')

# Import litstudy
path = os.path.abspath(os.path.join('..'))
if path not in sys.path:
    sys.path.append(path)

import litstudy

# %%
docs = litstudy.load_bibtex('monitoreo/scopus.bib')

# %%
print(len(docs), 'papers laoades')
# Out:
# 2317 papers laoades

# %%
corpus = litstudy.build_corpus(docs, ngram_threshold=0.8)

# %%
litstudy.compute_word_distribution(corpus).filter(like='_', axis=0).sort_index()
# Out:
#                           count
# academy_sciences              7
# aeronautics_astronautics     15
# arduino_uno                  48
# artificial_intelligence      39
# astronautical_federation     18
# ...                         ...
# unmanned_aerial              39
# vice_versa                    6
# wavelet_transform             5
# wiley_vch                    10
# wydawnictwo_sigma             6
#
# [86 rows x 1 columns]

# %%
plt.figure(figsize=(20, 3))
litstudy.plot_word_distribution(corpus, limit=50, title="Top words", vertical=True, label_rotation=45);
plt.savefig('histogra.png',bbox_inches='tight')

# %%
num_topics = 15
topic_model = litstudy.train_nmf_model(corpus, num_topics, max_iter=250)

# %%
for i in range(num_topics):
    print(f'Topic {i+1}:', topic_model.best_tokens_for_topic(i))
# Out:
# Topic 1: ['fault', 'detection', 'array', 'diagnosis', 'classification']
# Topic 2: ['water', 'quality', 'pump', 'lake', 'fish']
# Topic 3: ['mppt', 'converter', 'maximum', 'charging', 'battery']
# Topic 4: ['dust', 'cleaning', 'accumulation', 'deposition', 'surface']
# Topic 5: ['structure', 'robot', 'materials', 'module', 'bridge']
# Topic 6: ['image', 'satellite', 'uav', 'detection', 'defects']
# Topic 7: ['plant', 'model', 'prediction', 'photovoltaic', 'module']
# Topic 8: ['grid', 'electrical', 'renewable', 'generation', 'source']
# Topic 9: ['soil', 'irrigation', 'moisture', 'agriculture', 'crop']
# Topic 10: ['tracking', 'sun', 'tracker', 'axis', 'dual_axis']
# Topic 11: ['wind', 'turbine', 'vehicle', 'hybrid', 'station']
# Topic 12: ['iot', 'internet', 'things', 'internet_things', 'smart']
# Topic 13: ['heat', 'thermal', 'building', 'cooling', 'air']
# Topic 14: ['light', 'street', 'street_lights', 'intensity', 'voltage']
# Topic 15: ['node', 'wireless', 'sensor', 'network', 'wsn']

# %%
plt.figure(figsize=(15, 5))
litstudy.plot_topic_clouds(topic_model, ncols=5);
plt.savefig('cloud.png',bbox_inches='tight')

# %%
plt.figure(figsize=(20, 20))
litstudy.plot_embedding(corpus, topic_model);
plt.savefig('graphs.png',bbox_inches='tight')

# %%
topic_id = topic_model.best_topic_for_token('iot')
